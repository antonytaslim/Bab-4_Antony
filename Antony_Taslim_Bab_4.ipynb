# %% [markdown]
# <a href="https://colab.research.google.com/github/antonytaslim/Bab-4_Antony/blob/main/Antony_Taslim_Bab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("halo, taslim")
# Out:
# halo, taslim
